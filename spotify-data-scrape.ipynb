# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Set your Spotify API credentials
CLIENT_ID = '092acd03f5ca40e0a3dd8259ecab98e7'
CLIENT_SECRET = '75c44b710561420aad7c7d5b1afad2ae'

# Initialize Spotify API client
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_track_info(track_name, artist_name):
    # Search for the track
    results = sp.search(q=f'track:{track_name} artist:{artist_name}', type='track', limit=1)

    # Check if any results were found
    if results['tracks']['items']:
        track = results['tracks']['items'][0]
        print(f"Track Name: {track['name']}")
        print(f"Artist(s): {', '.join([artist['name'] for artist in track['artists']])}")
        print(f"Album: {track['album']['name']}")
        print(f"Release Date: {track['album']['release_date']}")
        print(f"Popularity: {track['popularity']}")
        print(f"Spotify URL: {track['external_urls']['spotify']}")
        
        # Retrieve and print audio features
        audio_features = sp.audio_features([track['id']])[0]
        print("\nAudio Features:")
        print(f"Danceability: {audio_features['danceability']}")
        print(f"Energy: {audio_features['energy']}")
        print(f"Acousticness: {audio_features['acousticness']}")
        print(f"Duration (ms): {audio_features['duration_ms']}")
        print(f"Instrumentalness: {audio_features['instrumentalness']}")
        print(f"Key: {audio_features['key']}")
        print(f"Liveness: {audio_features['liveness']}")
        print(f"Mode: {audio_features['mode']}")
        print(f"Speechiness: {audio_features['speechiness']}")
        print(f"Tempo: {audio_features['tempo']}")
        print(f"Time Signature: {audio_features['time_signature']}")
        print(f"Valence: {audio_features['valence']}")
        
    else:
        print(results['tracks']['items'])
        print(f"No results found for '{track_name}' by '{artist_name}'")

# Example usage
#track_name = "Um Bom Lugar"
track_name = "Um Lugar"
artist_name = "Pablo"

get_track_info(track_name, artist_name)
# Out:
# []
# No results found for 'Um Lugar' by 'Pablo'

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import sys
from pprint import pprint
 
# Set your Spotify API credentials
CLIENT_ID = '092acd03f5ca40e0a3dd8259ecab98e7'
CLIENT_SECRET = '75c44b710561420aad7c7d5b1afad2ae'

# Initialize Spotify API client
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

urn = 'spotify:track:0Svkvt5I79wficMFgaqEQJ'

track = sp.track(urn)
pprint(track)
# Out:
# {'album': {'album_type': 'album',
#            'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'},
#                         'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu',
#                         'id': '3jOstUTkEu2JkjvRdBA5Gu',
#                         'name': 'Weezer',
#                         'type': 'artist',
#                         'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}],
#            'available_markets': [],
#            'external_urls': {'spotify': 'https://open.spotify.com/album/04xe676vyiTeYNXw15o9jT'},
#            'href': 'https://api.spotify.com/v1/albums/04xe676vyiTeYNXw15o9jT',
#            'id': '04xe676vyiTeYNXw15o9jT',
#            'images': [{'height': 640,
#                        'url': 'https://i.scdn.co/image/ab67616d0000b273baee44673c99e67745a9b8d0',
#                        'width': 640},
#                       {'height': 300,
# ...

# %%
search_str = 'Radiohead'

result = sp.search(search_str)
pprint(result)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Radiohead&type=track&offset=0&limit=10',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#                                               'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#                                               'id': '4Z8W4fKeB5YxbusRsdQVPb',
#                                               'name': 'Radiohead',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#                                  'available_markets': ['AR',
#                                                        'AU',
#                                                        'AT',
#                                                        'BE',
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from pprint import pprint

CLIENT_ID = '092acd03f5ca40e0a3dd8259ecab98e7'
CLIENT_SECRET = '75c44b710561420aad7c7d5b1afad2ae'

client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_track_info(track_name, artist_name):
    results = sp.search(q=f'track:{track_name} artist:{artist_name}', type='track', limit=1)

    if results['tracks']['items']:
        track = results['tracks']['items'][0]
        pprint(track)
        audio_features = sp.audio_features([track['id']])[0]
        print("-----------------------------------------------------------------------------------------------")
        pprint(audio_features)
        audio_analysis = sp.audio_analysis(track['id'])
        print("-----------------------------------------------------------------------------------------------")
        pprint(audio_analysis)
    else:
        print(f"No results found for '{track_name}' by '{artist_name}'")

# Example usage
track_name = "Um Bom Lugar"
artist_name = "Sabotage"

get_track_info(track_name, artist_name)
# Out:
# {'album': {'album_type': 'album',
#            'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5deK5HnwbEKvge2svL0i0B'},
#                         'href': 'https://api.spotify.com/v1/artists/5deK5HnwbEKvge2svL0i0B',
#                         'id': '5deK5HnwbEKvge2svL0i0B',
#                         'name': 'Sabotage',
#                         'type': 'artist',
#                         'uri': 'spotify:artist:5deK5HnwbEKvge2svL0i0B'}],
#            'available_markets': ['AR',
#                                  'AU',
#                                  'AT',
#                                  'BE',
#                                  'BO',
#                                  'BR',
#                                  'BG',
#                                  'CA',
#                                  'CL',
#                                  'CO',
#                                  'CR',
#                                  'CY',
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_track_info(track_name, artist_name):
    # Search for the track
    results = sp.search(q=f'track:{track_name} artist:{artist_name}', type='track', limit=1)

    # Check if any results were found
    if results['tracks']['items']:
        track = results['tracks']['items'][0]
        print(f"Track Name: {track['name']}")
        print(f"Artist(s): {', '.join([artist['name'] for artist in track['artists']])}")
        print(f"Album: {track['album']['name']}")
        print(f"Release Date: {track['album']['release_date']}")
        print(f"Popularity: {track['popularity']}")
        print(f"Spotify URL: {track['external_urls']['spotify']}")
        
        # Retrieve and print audio features with confidence
        audio_analysis = sp.audio_analysis(track['id'])
        audio_features = audio_analysis['track']['features']
        
        print("\nAudio Features:")
        for feature, value in audio_features.items():
            print(f"{feature.capitalize()}: {value['valence']} (Confidence: {value['confidence']:.2f})")

    else:
        print(f"No results found for '{track_name}' by '{artist_name}'")

# Example usage
track_name = "Um Bom Lugar"
artist_name = "Sabotage"

get_track_info(track_name, artist_name)

# %%
import pandas

# %%
# !ls
# Out:
# Chords2MIDI.ipynb		geckodriver.log
# cifra				musicas-brasileiras-classicas.txt
# cifras				README.md
# cifras2				sitemap
# cifras.csv			sitemap_index.xml
# cifras-data-availability.ipynb	sitemap_index.xml.gz
# cifras_scraper.log		songs_list_br.ipynb
# cifras_scraper.py		spotify-data-scrape.ipynb
# cifra-web-scrape-study.ipynb

# %%
import pandas as pd

df = pd.read_csv("cifras.csv")
print(df)
# Out:
#    url_artist               url_song  \
# 0  evan craft  dios de oportunidades
#
#                                 cifra_file_loc cifra_key  \
# 0  cifras/evan-craft/dios-de-oportunidades.txt         G
#
#          spotify_artist           spotify_song          spotify_album  \
# 0  Evan Craft, Ke'Erron  Dios De Oportunidades  Dios De Oportunidades
#
#    spotify_popularity release_date  feature_danceability  ...  feature_key  \
# 0                  47   2023-09-15                 0.522  ...            7
#
#    feature_liveness  feature_mode  feature_speechiness  feature_tempo  \
# 0             0.103             1               0.0316          130.0
#
#    feature_time_signature  feature_valence  song_duration  \
# 0                       4            0.174         244406
#
#                                            cifra_url  \
# 0  https://www.cifras.com.br/cifra/evan-craft/dio...
#
#                                          spotify_url
# ...

# %%
import os

def check_free_space(folder_path):
    """Checks the available free space in the specified folder.

    Args:
        folder_path (str): The path to the folder to check.

    Returns:
        tuple: A tuple containing (free_space_bytes, total_space_bytes)
    """

    statvfs = os.statvfs(folder_path)
    free_space = statvfs.f_bavail * statvfs.f_frsize
    return free_space

# Get the path to your home folder
home_folder = os.path.expanduser("~")  # Expands "~" to the full path

# Check the free space
free_space_bytes = check_free_space(home_folder)

# Convert bytes to gigabytes for readability
free_space_gb = free_space_bytes / (1024 * 1024 * 1024)

print(f"Free space in home folder: {free_space_gb:.2f} GB")
# Out:
# Free space in home folder: 190.70 GB
